# %% [markdown]
# # New functions and methods tests
# Tests for the development of new functions or methods

# %%
import os
import pandas as pd
import sys

# %% [markdown]
# #### CheckOutliers.plot_outliers

# %%
# %load_ext autoreload
# %autoreload 2

cwd = os.getcwd()
cwd = os.path.sep.join(cwd.split(os.path.sep)[:-1])
sys.path.insert(1, os.path.join(cwd))
from dataanalysis import CheckOutliers

# %%
df = pd.read_csv(os.path.join(cwd, 'tests', 'gw-ts-fill-v3.csv'), index_col='Data', parse_dates=True)

# %%
co = CheckOutliers(df, printinfo=False, saveoutliers=True)

# %%
keys = [*co.outliers]

# %%
#extract the outliers from df
test = df.copy()
code = keys[0]
test.loc[co.outliers[code], code]
# Out:
# Data
# 2005-09-01    206.032
# 2007-09-01    206.292
# 2007-10-01    206.292
# Name: PO013064NU0002, dtype: float64

# %%
fig, ax = co.plot_outliers(column=code, ret = True)
ax.set_ylabel('[m.s.l.m.]')
# Out:
# Text(0, 0.5, '[m.s.l.m.]')

# %%
fig, ax = co.plot_outliers(column=keys[5], ret = True)
ax.set_ylabel('[m.s.l.m.]')
# Out:
# Text(0, 0.5, '[m.s.l.m.]')

# %% [markdown]
# #### CheckOutilers.plot_perc

# %%
co.plot_bar()

# %%
co.df.shape[1]//5
# Out:
# 10
